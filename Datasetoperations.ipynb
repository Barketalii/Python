# %% [markdown]
# <a href="https://colab.research.google.com/github/Barketalii/Python/blob/main/Datasetoperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data={
       'name':['ali','mohd','hussain'],
       'age':[24,23,25],
       'marks':[80,90,60],
       }

# %%
data
# Out:
# {'name': ['ali', 'mohd', 'hussain'],
#  'age': [24, 23, 25],
#  'marks': [80, 90, 60]}

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv('Monthly_rates.csv')#reads the csv file so that after uploading the file we can perform the operation on it

# %%
df
# Out:
#            State   Season  _YearMonth AgeCategory_Legend Sex_Label  \
# 0           Utah  2021-22    202110.0                All       All
# 1           Utah  2021-22    202204.0                All       All
# 2           Utah  2021-22    202208.0                All       All
# 3           Utah  2021-22    202201.0                All       All
# 4           Utah  2021-22    202112.0                All       All
# ...          ...      ...         ...                ...       ...
# 43057  COVID-NET  2024-25    202504.0                All       All
# 43058  COVID-NET  2024-25    202412.0                All       All
# 43059  COVID-NET  2024-25    202506.0                All       All
# 43060  COVID-NET  2024-25    202508.0                All       All
# 43061  COVID-NET  2024-25    202509.0                All       All
#
#                 Race_Label  MonthlyRate               Type
# 0                      All         39.8         Crude Rate
# 1                      All          7.1         Crude Rate
# 2                      All         24.4         Crude Rate
# 3                      All        104.2         Crude Rate
# 4                      All         38.9         Crude Rate
# ...                    ...          ...                ...
# 43057  White, non-Hispanic          NaN  Age adjusted Rate
# 43058  White, non-Hispanic          NaN  Age adjusted Rate
# 43059  White, non-Hispanic          NaN  Age adjusted Rate
# 43060  White, non-Hispanic          NaN  Age adjusted Rate
# 43061  White, non-Hispanic          NaN  Age adjusted Rate
#
# [43062 rows x 8 columns]

# %%
df.head()#Shows first n rows (default 5).
# Out:
#   State   Season  _YearMonth AgeCategory_Legend Sex_Label Race_Label  \
# 0  Utah  2021-22    202110.0                All       All        All
# 1  Utah  2021-22    202204.0                All       All        All
# 2  Utah  2021-22    202208.0                All       All        All
# 3  Utah  2021-22    202201.0                All       All        All
# 4  Utah  2021-22    202112.0                All       All        All
#
#    MonthlyRate        Type
# 0         39.8  Crude Rate
# 1          7.1  Crude Rate
# 2         24.4  Crude Rate
# 3        104.2  Crude Rate
# 4         38.9  Crude Rate

# %%
df.tail()#Shows last n rows (default 5).
# Out:
#            State   Season  _YearMonth AgeCategory_Legend Sex_Label  \
# 43057  COVID-NET  2024-25    202504.0                All       All
# 43058  COVID-NET  2024-25    202412.0                All       All
# 43059  COVID-NET  2024-25    202506.0                All       All
# 43060  COVID-NET  2024-25    202508.0                All       All
# 43061  COVID-NET  2024-25    202509.0                All       All
#
#                 Race_Label  MonthlyRate               Type
# 43057  White, non-Hispanic          NaN  Age adjusted Rate
# 43058  White, non-Hispanic          NaN  Age adjusted Rate
# 43059  White, non-Hispanic          NaN  Age adjusted Rate
# 43060  White, non-Hispanic          NaN  Age adjusted Rate
# 43061  White, non-Hispanic          NaN  Age adjusted Rate

# %%
df.info()#Summary: column names, non-null counts, datatypes, memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43062 entries, 0 to 43061
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               43062 non-null  object
#  1   Season              43062 non-null  object
#  2   _YearMonth          43062 non-null  float64
#  3   AgeCategory_Legend  43062 non-null  object
#  4   Sex_Label           43062 non-null  object
#  5   Race_Label          43062 non-null  object
#  6   MonthlyRate         42119 non-null  float64
#  7   Type                43062 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 2.6+ MB

# %%
df.describe()#Summary statistics (count, mean, std, min, 25%, 50%, 75%, max)
# Out:
#           _YearMonth   MonthlyRate
# count   43062.000000  42119.000000
# mean   202244.983419     31.160913
# std       160.988193     61.430085
# min    202003.000000      0.000000
# 25%    202107.000000      2.900000
# 50%    202211.000000     10.900000
# 75%    202404.000000     32.400000
# max    202509.000000   1260.000000

# %%
df.shape  #Returns (rows, columns).
# Out:
# (43062, 8)

# %%
df.columns #List of column names.
# Out:
# Index(['State', 'Season', '_YearMonth', 'AgeCategory_Legend', 'Sex_Label',
#        'Race_Label', 'MonthlyRate', 'Type'],
#       dtype='object')

# %%
df.index #Index (row labels)
# Out:
# RangeIndex(start=0, stop=43062, step=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=43062, step=1)

# %%
df.dtypes #Data types of columns
# Out:
# State                  object
# Season                 object
# _YearMonth            float64
# AgeCategory_Legend     object
# Sex_Label              object
# Race_Label             object
# MonthlyRate           float64
# Type                   object
# dtype: object

# %% [markdown]
# Selection and filtering

# %%
df['Sex_Label'] #Select single column.
# Out:
# 0        All
# 1        All
# 2        All
# 3        All
# 4        All
#         ...
# 43057    All
# 43058    All
# 43059    All
# 43060    All
# 43061    All
# Name: Sex_Label, Length: 43062, dtype: object

# %%
df[["Sex_Label","Season","Race_Label"]] #used to select multiple columns at a time
# Out:
#       Sex_Label   Season           Race_Label           Race_Label
# 0           All  2021-22                  All                  All
# 1           All  2021-22                  All                  All
# 2           All  2021-22                  All                  All
# 3           All  2021-22                  All                  All
# 4           All  2021-22                  All                  All
# ...         ...      ...                  ...                  ...
# 43057       All  2024-25  White, non-Hispanic  White, non-Hispanic
# 43058       All  2024-25  White, non-Hispanic  White, non-Hispanic
# 43059       All  2024-25  White, non-Hispanic  White, non-Hispanic
# 43060       All  2024-25  White, non-Hispanic  White, non-Hispanic
# 43061       All  2024-25  White, non-Hispanic  White, non-Hispanic
#
# [43062 rows x 4 columns]

# %%
df.loc[3,'Season'] #uses labels
# Out:
# '2021-22'

# %%
df.iloc[0] # uses integer positions
# Out:
# State                       Utah
# Season                   2021-22
# _YearMonth              202110.0
# AgeCategory_Legend           All
# Sex_Label                    All
# Race_Label                   All
# MonthlyRate                 39.8
# Type                  Crude Rate
# Name: 0, dtype: object

# %% [markdown]
# df[df['columnname'] > 10 ] runs a condition on dataframe and returns the output satisfying the given condition

# %%
df[df['_YearMonth'] > 10] # i had taken Race_Label as column and put condition on it that didn't work as Race_Label was holding strings
# Out:
#            State   Season  _YearMonth AgeCategory_Legend Sex_Label  \
# 0           Utah  2021-22    202110.0                All       All
# 1           Utah  2021-22    202204.0                All       All
# 2           Utah  2021-22    202208.0                All       All
# 3           Utah  2021-22    202201.0                All       All
# 4           Utah  2021-22    202112.0                All       All
# ...          ...      ...         ...                ...       ...
# 43057  COVID-NET  2024-25    202504.0                All       All
# 43058  COVID-NET  2024-25    202412.0                All       All
# 43059  COVID-NET  2024-25    202506.0                All       All
# 43060  COVID-NET  2024-25    202508.0                All       All
# 43061  COVID-NET  2024-25    202509.0                All       All
#
#                 Race_Label  MonthlyRate               Type
# 0                      All         39.8         Crude Rate
# 1                      All          7.1         Crude Rate
# 2                      All         24.4         Crude Rate
# 3                      All        104.2         Crude Rate
# 4                      All         38.9         Crude Rate
# ...                    ...          ...                ...
# 43057  White, non-Hispanic          NaN  Age adjusted Rate
# 43058  White, non-Hispanic          NaN  Age adjusted Rate
# 43059  White, non-Hispanic          NaN  Age adjusted Rate
# 43060  White, non-Hispanic          NaN  Age adjusted Rate
# 43061  White, non-Hispanic          NaN  Age adjusted Rate
#
# [43062 rows x 8 columns]

# %%
df.query('_YearMonth > 10 & MonthlyRate > 50') #SQL like query
# Out:
#            State   Season  _YearMonth AgeCategory_Legend Sex_Label  \
# 3           Utah  2021-22    202201.0                All       All
# 21          Utah  2021-22    202201.0                All       All
# 33          Utah  2021-22    202201.0                All       All
# 36          Utah  2021-22    202111.0                All       All
# 39          Utah  2021-22    202202.0                All       All
# ...          ...      ...         ...                ...       ...
# 42984  COVID-NET  2019-20    202007.0                All       All
# 42986  COVID-NET  2019-20    202005.0                All       All
# 42988  COVID-NET  2019-20    202004.0                All       All
# 42990  COVID-NET  2019-20    202007.0                All       All
# 42992  COVID-NET  2019-20    202005.0                All       All
#
#                 Race_Label  MonthlyRate               Type
# 3                      All        104.2         Crude Rate
# 21                Hispanic         98.0         Crude Rate
# 33      A/PI, non-Hispanic        177.5         Crude Rate
# 36     AI/AN, non-Hispanic         61.8         Crude Rate
# 39     AI/AN, non-Hispanic         61.8         Crude Rate
# ...                    ...          ...                ...
# 42984  AI/AN, non-Hispanic         54.7  Age adjusted Rate
# 42986  AI/AN, non-Hispanic        136.4  Age adjusted Rate
# 42988  Black, non-Hispanic         93.4  Age adjusted Rate
# 42990  Black, non-Hispanic         76.7  Age adjusted Rate
# 42992  Black, non-Hispanic         62.5  Age adjusted Rate
#
# [6954 rows x 8 columns]

# %%
df.isnull()
# Out:
#        State  Season  _YearMonth  AgeCategory_Legend  Sex_Label  Race_Label  \
# 0      False   False       False               False      False       False
# 1      False   False       False               False      False       False
# 2      False   False       False               False      False       False
# 3      False   False       False               False      False       False
# 4      False   False       False               False      False       False
# ...      ...     ...         ...                 ...        ...         ...
# 43057  False   False       False               False      False       False
# 43058  False   False       False               False      False       False
# 43059  False   False       False               False      False       False
# 43060  False   False       False               False      False       False
# 43061  False   False       False               False      False       False
#
#        MonthlyRate   Type
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ...            ...    ...
# 43057         True  False
# 43058         True  False
# 43059         True  False
# 43060         True  False
# 43061         True  False
#
# [43062 rows x 8 columns]

# %%
df['MonthlyRate']
# Out:
# 0         39.8
# 1          7.1
# 2         24.4
# 3        104.2
# 4         38.9
#          ...
# 43057      NaN
# 43058      NaN
# 43059      NaN
# 43060      NaN
# 43061      NaN
# Name: MonthlyRate, Length: 43062, dtype: float64

# %% [markdown]
# **Sorting and Ranking**

# %%
df.sort_values('_YearMonth').tail(5)# sort by column (ascending by default)
# Out:
#            State   Season  _YearMonth AgeCategory_Legend Sex_Label  \
# 43015  COVID-NET  2024-25    202509.0                All       All
# 43033  COVID-NET  2024-25    202509.0                All       All
# 43044  COVID-NET  2024-25    202509.0                All       All
# 43003  COVID-NET  2024-25    202509.0                All       All
# 43061  COVID-NET  2024-25    202509.0                All       All
#
#                 Race_Label  MonthlyRate               Type
# 43015   A/PI, non-Hispanic          NaN  Age adjusted Rate
# 43033  AI/AN, non-Hispanic          NaN  Age adjusted Rate
# 43044  Black, non-Hispanic          NaN  Age adjusted Rate
# 43003             Hispanic          NaN  Age adjusted Rate
# 43061  White, non-Hispanic          NaN  Age adjusted Rate

# %%
df.sort_values(['_YearMonth','MonthlyRate'],ascending=[True,False])#sort Multi coolumn
# Out:
#            State   Season  _YearMonth  AgeCategory_Legend Sex_Label  \
# 28111   Colorado  2019-20    202003.0           ≥85 years       All
# 35230   Michigan  2019-20    202003.0  ≥18 years (Adults)       All
# 25805  Tennessee  2019-20    202003.0           ≥85 years       All
# 27693    Georgia  2019-20    202003.0           ≥85 years       All
# 27067   Michigan  2019-20    202003.0           ≥85 years       All
# ...          ...      ...         ...                 ...       ...
# 43003  COVID-NET  2024-25    202509.0                 All       All
# 43015  COVID-NET  2024-25    202509.0                 All       All
# 43033  COVID-NET  2024-25    202509.0                 All       All
# 43044  COVID-NET  2024-25    202509.0                 All       All
# 43061  COVID-NET  2024-25    202509.0                 All       All
#
#                 Race_Label  MonthlyRate               Type
# 28111                  All        172.5         Crude Rate
# 35230  Black, non-Hispanic        165.4         Crude Rate
# 25805                  All        161.0         Crude Rate
# 27693                  All        146.0         Crude Rate
# 27067                  All        140.5         Crude Rate
# ...                    ...          ...                ...
# 43003             Hispanic          NaN  Age adjusted Rate
# 43015   A/PI, non-Hispanic          NaN  Age adjusted Rate
# 43033  AI/AN, non-Hispanic          NaN  Age adjusted Rate
# 43044  Black, non-Hispanic          NaN  Age adjusted Rate
# 43061  White, non-Hispanic          NaN  Age adjusted Rate
#
# [43062 rows x 8 columns]

# %%
df.sort_index() #sort by index
# Out:
#            State   Season  _YearMonth AgeCategory_Legend Sex_Label  \
# 0           Utah  2021-22    202110.0                All       All
# 1           Utah  2021-22    202204.0                All       All
# 2           Utah  2021-22    202208.0                All       All
# 3           Utah  2021-22    202201.0                All       All
# 4           Utah  2021-22    202112.0                All       All
# ...          ...      ...         ...                ...       ...
# 43057  COVID-NET  2024-25    202504.0                All       All
# 43058  COVID-NET  2024-25    202412.0                All       All
# 43059  COVID-NET  2024-25    202506.0                All       All
# 43060  COVID-NET  2024-25    202508.0                All       All
# 43061  COVID-NET  2024-25    202509.0                All       All
#
#                 Race_Label  MonthlyRate               Type
# 0                      All         39.8         Crude Rate
# 1                      All          7.1         Crude Rate
# 2                      All         24.4         Crude Rate
# 3                      All        104.2         Crude Rate
# 4                      All         38.9         Crude Rate
# ...                    ...          ...                ...
# 43057  White, non-Hispanic          NaN  Age adjusted Rate
# 43058  White, non-Hispanic          NaN  Age adjusted Rate
# 43059  White, non-Hispanic          NaN  Age adjusted Rate
# 43060  White, non-Hispanic          NaN  Age adjusted Rate
# 43061  White, non-Hispanic          NaN  Age adjusted Rate
#
# [43062 rows x 8 columns]

# %%
df.rank()
# Out:
#          State   Season  _YearMonth  AgeCategory_Legend  Sex_Label  \
# 0      41610.5  16800.5     13104.5             28570.0    18565.5
# 1      41610.5  16800.5     17136.5             28570.0    18565.5
# 2      41610.5  16800.5     19824.5             28570.0    18565.5
# 3      41610.5  16800.5     15120.5             28570.0    18565.5
# 4      41610.5  16800.5     14448.5             28570.0    18565.5
# ...        ...      ...         ...                 ...        ...
# 43057   1620.0  39567.5     40200.0             28570.0    18565.5
# 43058   1620.0  39567.5     37660.0             28570.0    18565.5
# 43059   1620.0  39567.5     41470.0             28570.0    18565.5
# 43060   1620.0  39567.5     42740.0             28570.0    18565.5
# 43061   1620.0  39567.5     43060.0             28570.0    18565.5
#
#        Race_Label  MonthlyRate     Type
# 0         20015.0      33373.5  21699.0
# 1         20015.0      17245.0  21699.0
# 2         20015.0      28968.5  21699.0
# 3         20015.0      39183.0  21699.0
# 4         20015.0      33196.5  21699.0
# ...           ...          ...      ...
# 43057     41546.0          NaN    168.0
# 43058     41546.0          NaN    168.0
# 43059     41546.0          NaN    168.0
# 43060     41546.0          NaN    168.0
# 43061     41546.0          NaN    168.0
#
# [43062 rows x 8 columns]

# %% [markdown]
# **Handling missing values**

# %%
df.isnull() #detect missing values(NaN)
# Out:
#        State  Season  _YearMonth  AgeCategory_Legend  Sex_Label  Race_Label  \
# 0      False   False       False               False      False       False
# 1      False   False       False               False      False       False
# 2      False   False       False               False      False       False
# 3      False   False       False               False      False       False
# 4      False   False       False               False      False       False
# ...      ...     ...         ...                 ...        ...         ...
# 43057  False   False       False               False      False       False
# 43058  False   False       False               False      False       False
# 43059  False   False       False               False      False       False
# 43060  False   False       False               False      False       False
# 43061  False   False       False               False      False       False
#
#        MonthlyRate   Type
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ...            ...    ...
# 43057         True  False
# 43058         True  False
# 43059         True  False
# 43060         True  False
# 43061         True  False
#
# [43062 rows x 8 columns]

# %%
df.notnull() #detect non-missing values
# Out:
#        State  Season  _YearMonth  AgeCategory_Legend  Sex_Label  Race_Label  \
# 0       True    True        True                True       True        True
# 1       True    True        True                True       True        True
# 2       True    True        True                True       True        True
# 3       True    True        True                True       True        True
# 4       True    True        True                True       True        True
# ...      ...     ...         ...                 ...        ...         ...
# 43057   True    True        True                True       True        True
# 43058   True    True        True                True       True        True
# 43059   True    True        True                True       True        True
# 43060   True    True        True                True       True        True
# 43061   True    True        True                True       True        True
#
#        MonthlyRate  Type
# 0             True  True
# 1             True  True
# 2             True  True
# 3             True  True
# 4             True  True
# ...            ...   ...
# 43057        False  True
# 43058        False  True
# 43059        False  True
# 43060        False  True
# 43061        False  True
#
# [43062 rows x 8 columns]

# %%
df.info() #gives all information about the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43062 entries, 0 to 43061
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               43062 non-null  object
#  1   Season              43062 non-null  object
#  2   _YearMonth          43062 non-null  float64
#  3   AgeCategory_Legend  43062 non-null  object
#  4   Sex_Label           43062 non-null  object
#  5   Race_Label          43062 non-null  object
#  6   MonthlyRate         42119 non-null  float64
#  7   Type                43062 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 2.6+ MB

# %%
df.fillna(df['MonthlyRate'].mean())
# Out:
#            State   Season  _YearMonth AgeCategory_Legend Sex_Label  \
# 0           Utah  2021-22    202110.0                All       All
# 1           Utah  2021-22    202204.0                All       All
# 2           Utah  2021-22    202208.0                All       All
# 3           Utah  2021-22    202201.0                All       All
# 4           Utah  2021-22    202112.0                All       All
# ...          ...      ...         ...                ...       ...
# 43057  COVID-NET  2024-25    202504.0                All       All
# 43058  COVID-NET  2024-25    202412.0                All       All
# 43059  COVID-NET  2024-25    202506.0                All       All
# 43060  COVID-NET  2024-25    202508.0                All       All
# 43061  COVID-NET  2024-25    202509.0                All       All
#
#                 Race_Label  MonthlyRate               Type
# 0                      All    39.800000         Crude Rate
# 1                      All     7.100000         Crude Rate
# 2                      All    24.400000         Crude Rate
# 3                      All   104.200000         Crude Rate
# 4                      All    38.900000         Crude Rate
# ...                    ...          ...                ...
# 43057  White, non-Hispanic    31.160913  Age adjusted Rate
# 43058  White, non-Hispanic    31.160913  Age adjusted Rate
# 43059  White, non-Hispanic    31.160913  Age adjusted Rate
# 43060  White, non-Hispanic    31.160913  Age adjusted Rate
# 43061  White, non-Hispanic    31.160913  Age adjusted Rate
#
# [43062 rows x 8 columns]

# %%
df.fillna(10)# replaces NaN with the value 10
# Out:
#            State   Season  _YearMonth AgeCategory_Legend Sex_Label  \
# 0           Utah  2021-22    202110.0                All       All
# 1           Utah  2021-22    202204.0                All       All
# 2           Utah  2021-22    202208.0                All       All
# 3           Utah  2021-22    202201.0                All       All
# 4           Utah  2021-22    202112.0                All       All
# ...          ...      ...         ...                ...       ...
# 43057  COVID-NET  2024-25    202504.0                All       All
# 43058  COVID-NET  2024-25    202412.0                All       All
# 43059  COVID-NET  2024-25    202506.0                All       All
# 43060  COVID-NET  2024-25    202508.0                All       All
# 43061  COVID-NET  2024-25    202509.0                All       All
#
#                 Race_Label  MonthlyRate               Type
# 0                      All         39.8         Crude Rate
# 1                      All          7.1         Crude Rate
# 2                      All         24.4         Crude Rate
# 3                      All        104.2         Crude Rate
# 4                      All         38.9         Crude Rate
# ...                    ...          ...                ...
# 43057  White, non-Hispanic         10.0  Age adjusted Rate
# 43058  White, non-Hispanic         10.0  Age adjusted Rate
# 43059  White, non-Hispanic         10.0  Age adjusted Rate
# 43060  White, non-Hispanic         10.0  Age adjusted Rate
# 43061  White, non-Hispanic         10.0  Age adjusted Rate
#
# [43062 rows x 8 columns]

# %%
df.dropna()      # drops rows with Nan value
# Out:
#            State   Season  _YearMonth AgeCategory_Legend Sex_Label  \
# 0           Utah  2021-22    202110.0                All       All
# 1           Utah  2021-22    202204.0                All       All
# 2           Utah  2021-22    202208.0                All       All
# 3           Utah  2021-22    202201.0                All       All
# 4           Utah  2021-22    202112.0                All       All
# ...          ...      ...         ...                ...       ...
# 42997  COVID-NET  2019-20    202003.0                All       All
# 42998  COVID-NET  2019-20    202009.0                All       All
# 42999  COVID-NET  2019-20    202006.0                All       All
# 43000  COVID-NET  2019-20    202007.0                All       All
# 43001  COVID-NET  2019-20    202004.0                All       All
#
#                 Race_Label  MonthlyRate               Type
# 0                      All         39.8         Crude Rate
# 1                      All          7.1         Crude Rate
# 2                      All         24.4         Crude Rate
# 3                      All        104.2         Crude Rate
# 4                      All         38.9         Crude Rate
# ...                    ...          ...                ...
# 42997  White, non-Hispanic          8.7  Age adjusted Rate
# 42998  White, non-Hispanic         10.7  Age adjusted Rate
# 42999  White, non-Hispanic          7.7  Age adjusted Rate
# 43000  White, non-Hispanic         14.4  Age adjusted Rate
# 43001  White, non-Hispanic         20.9  Age adjusted Rate
#
# [42119 rows x 8 columns]

# %% [markdown]
# Aggregation & Statistics

# %%
df['MonthlyRate'].mean()
#df.mean() if all columns were integer or float since there are  strings also so woll show errors
# Out:
# np.float64(31.160913127092286)

# %%
df.mean() #this operation will calculate the mean of the numerical colums ignorig the other datatypes

# %%
df.median() #calculate the median of  the columns if there is numeric column

# %%
df.std()  #calculates the standard deviation of the numeric values ignoring the other data types

# %%
 df.corr()# computes the pair wise correlation between numeric columns.it ignores non numeric values

# %%
df.cov()#computes the pairwise covariance between numeric columns

# %% [markdown]
# Groupby(split-apply-combine)
